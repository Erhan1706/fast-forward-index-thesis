# %%
import pyterrier as pt


if not pt.started():
    # Set properties to handle longer terms and metadata
    pt.init(tqdm='notebook')
# Out:
# PyTerrier 0.10.1 has loaded Terrier 5.9 (built by craigm on 2024-05-02 17:40) and terrier-helper 0.0.8
#
# No etc/terrier.properties, using terrier.default.properties for bootstrap configuration.

# %%
pt.set_property("max.term.length", 200)
pt.set_property("indexer.meta.forward.keylens", 200)

# %%
dataset = pt.get_dataset("irds:beir/climate-fever")

# %%
indexer = pt.IterDictIndexer("./data/climate-fever", meta={'docno': 28}, overwrite=True, verbose=True)

# %%
index_ref = indexer.index(dataset.get_corpus_iter())
# Out:
# beir/climate-fever documents:   0%|          | 0/5416593 [00:00<?, ?it/s]
# 15:38:33.987 [ForkJoinPool-1-worker-1] WARN org.terrier.structures.indexing.Indexer - Adding an empty document to the index (1941_in_paleontology) - further warnings are suppressed
# 15:38:35.888 [ForkJoinPool-1-worker-1] ERROR org.terrier.structures.seralization.FixedSizeTextFactory - Term 16th_(Schleswig-Holstein)_Hussars_"Emperor_Francis_Joseph_of_Austria,_King_of_Hungary" written in 87 bytes. Max expected size was 85. Increase relevant property: max.term.length for Lexicon, or indexer.meta.forward.keylens for metadata
# java.lang.ArrayIndexOutOfBoundsException: arraycopy: length -2 is negative
# 	at java.base/java.lang.System.arraycopy(Native Method)
# 	at java.base/java.io.BufferedOutputStream.implWrite(BufferedOutputStream.java:224)
# 	at java.base/java.io.BufferedOutputStream.write(BufferedOutputStream.java:200)
# 	at java.base/java.io.DataOutputStream.write(DataOutputStream.java:115)
# ...
